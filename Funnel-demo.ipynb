# %% [markdown]
# # Demontration of neural network MCMC sampler trained with maximum Entropy objective

# %% [markdown]
# ## Please run Cells in the order provided.
#
# Requirements: pytorch 1.6.0 (cuda not required), numpy, matplotlib

# %% [markdown]
# ### First we import modules and setup the model

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from L2RW_models import L2GradRW, CovMALA
from L2RW import L2GradRW_M, adjust_lr
from distributions import distributions

# %%
data_dim = 2
dim = 32
N_steps = 2
dist = distributions('funnel',d=data_dim)
RW = L2GradRW(dist.Ex,data_dim,dim,N_steps,epsi=0.01,net_type='MLP',grad_mode='R',bias=True,act='elu') #diag_gaussian example use 0.001 epsi init
RW_controller = L2GradRW_M(RW,beta=1e-2,beta_max=1e3,rho_beta=0.1,adapt_beta=True,a_target=0.9,
                 lr=1e-3,momo=0.9,rms_momo=0.95,grad_norm=10,N_steps=5000)

# %% [markdown]
# ### Train the Sampler
#
# sldjxx is the proposal entropy (up to a constant equal to the entropy of Gaussian), it should increase during training

# %%
#train with real samples
bs = 512
for i in range(5000):
    x_init = dist.sample(bs) # Samples from true Funnel distribution.
    x, accept_rate, sldjxx, L2jump = RW_controller.sample_train(x_init,T=1,print_log= (True if i%100==0 else False))
    #adjust_lr(RW_controller,i,warmup=False,min_lr=1e-2)
    if i>5 and i%1000 == 0:
        print('1ksteps done, now {}'.format(i))
# Out:
# jump 9.992e-05, Exp jump9.992e-05, accept 1.000,log_a 3.792e-04, sldjxx -9.210,beta 1.010e-02, epsi 1.001e-02
# jump 1.893e-03, Exp jump1.836e-03, accept 0.988,log_a -1.720e-03, sldjxx -6.984,beta 2.639e-02, epsi 1.059e-02
# jump 1.106e-01, Exp jump1.032e-01, accept 0.954,log_a -1.995e-02, sldjxx -3.324,beta 5.294e-02, epsi 1.110e-02
# jump 3.527e-01, Exp jump3.311e-01, accept 0.949,log_a -1.359e-02, sldjxx -2.050,beta 8.684e-02, epsi 1.146e-02
# jump 5.573e-01, Exp jump5.065e-01, accept 0.924,log_a -4.275e-02, sldjxx -1.553,beta 1.209e-01, epsi 1.160e-02
# jump 7.308e-01, Exp jump6.593e-01, accept 0.914,log_a -8.059e-02, sldjxx -1.444,beta 1.495e-01, epsi 1.171e-02
# jump 9.754e-01, Exp jump8.665e-01, accept 0.910,log_a -8.799e-02, sldjxx -1.110,beta 1.656e-01, epsi 1.188e-02
# jump 1.283e+00, Exp jump1.098e+00, accept 0.895,log_a -6.938e-02, sldjxx -1.020,beta 1.713e-01, epsi 1.201e-02
# jump 1.411e+00, Exp jump1.175e+00, accept 0.912,log_a -4.487e-02, sldjxx -0.902,beta 1.743e-01, epsi 1.214e-02
# jump 1.574e+00, Exp jump1.269e+00, accept 0.885,log_a -8.197e-02, sldjxx -0.647,beta 1.744e-01, epsi 1.226e-02
# jump 1.648e+00, Exp jump1.299e+00, accept 0.920,log_a -1.650e-02, sldjxx -0.568,beta 1.784e-01, epsi 1.242e-02
# 1ksteps done, now 1000
# jump 2.660e+00, Exp jump2.234e+00, accept 0.904,log_a -5.988e-02, sldjxx -0.425,beta 1.846e-01, epsi 1.257e-02
# jump 2.279e+00, Exp jump1.997e+00, accept 0.916,log_a -5.867e-02, sldjxx -0.340,beta 1.944e-01, epsi 1.271e-02
# jump 3.346e+00, Exp jump3.068e+00, accept 0.921,log_a -3.153e-02, sldjxx -0.076,beta 2.170e-01, epsi 1.287e-02
# jump 3.364e+00, Exp jump2.610e+00, accept 0.901,log_a -6.572e-02, sldjxx 0.069,beta 2.445e-01, epsi 1.299e-02
# jump 5.274e+00, Exp jump4.070e+00, accept 0.912,log_a -7.600e-02, sldjxx 0.170,beta 2.713e-01, epsi 1.310e-02
# jump 7.509e+00, Exp jump6.400e+00, accept 0.905,log_a -7.226e-02, sldjxx 0.369,beta 3.056e-01, epsi 1.319e-02
# jump 7.824e+00, Exp jump6.672e+00, accept 0.907,log_a -6.649e-02, sldjxx 0.359,beta 3.126e-01, epsi 1.330e-02
# jump 9.622e+00, Exp jump7.892e+00, accept 0.925,log_a -5.022e-02, sldjxx 0.190,beta 3.287e-01, epsi 1.332e-02
# jump 1.083e+01, Exp jump8.853e+00, accept 0.910,log_a -7.108e-02, sldjxx 0.426,beta 3.660e-01, epsi 1.343e-02
# jump 1.132e+01, Exp jump9.363e+00, accept 0.908,log_a -1.104e-01, sldjxx 0.630,beta 3.727e-01, epsi 1.347e-02
# 1ksteps done, now 2000
# jump 1.196e+01, Exp jump1.060e+01, accept 0.886,log_a -9.162e-02, sldjxx 0.507,beta 3.666e-01, epsi 1.354e-02
# jump 1.421e+01, Exp jump1.021e+01, accept 0.899,log_a -1.009e-01, sldjxx 0.773,beta 3.816e-01, epsi 1.361e-02
# jump 1.597e+01, Exp jump1.256e+01, accept 0.905,log_a -7.005e-02, sldjxx 0.670,beta 3.994e-01, epsi 1.366e-02
# jump 1.575e+01, Exp jump9.637e+00, accept 0.889,log_a -9.117e-02, sldjxx 0.714,beta 4.177e-01, epsi 1.373e-02
# jump 1.569e+01, Exp jump1.158e+01, accept 0.903,log_a -1.433e-01, sldjxx 0.744,beta 4.203e-01, epsi 1.379e-02
# jump 1.918e+01, Exp jump1.174e+01, accept 0.888,log_a -1.193e-01, sldjxx 0.801,beta 4.135e-01, epsi 1.383e-02
# jump 1.479e+01, Exp jump1.038e+01, accept 0.873,log_a -1.685e-01, sldjxx 0.796,beta 4.147e-01, epsi 1.387e-02
# jump 2.129e+01, Exp jump1.207e+01, accept 0.873,log_a -1.851e-01, sldjxx 0.809,beta 4.083e-01, epsi 1.394e-02
# jump 1.896e+01, Exp jump1.397e+01, accept 0.878,log_a -2.226e-01, sldjxx 0.795,beta 3.975e-01, epsi 1.395e-02
# jump 2.294e+01, Exp jump1.856e+01, accept 0.906,log_a -6.521e-02, sldjxx 0.892,beta 4.106e-01, epsi 1.402e-02
# 1ksteps done, now 3000
# jump 1.327e+01, Exp jump1.129e+01, accept 0.905,log_a -1.367e-01, sldjxx 0.724,beta 4.241e-01, epsi 1.407e-02
# jump 1.860e+01, Exp jump1.135e+01, accept 0.911,log_a -6.975e-02, sldjxx 0.720,beta 4.200e-01, epsi 1.411e-02
# jump 1.844e+01, Exp jump1.285e+01, accept 0.870,log_a -1.683e-01, sldjxx 0.842,beta 4.099e-01, epsi 1.414e-02
# jump 1.583e+01, Exp jump9.217e+00, accept 0.887,log_a -1.108e-01, sldjxx 0.901,beta 4.023e-01, epsi 1.416e-02
# jump 2.845e+01, Exp jump2.144e+01, accept 0.905,log_a -7.125e-02, sldjxx 0.725,beta 4.039e-01, epsi 1.421e-02
# jump 1.464e+01, Exp jump1.206e+01, accept 0.904,log_a -7.192e-02, sldjxx 0.728,beta 3.766e-01, epsi 1.424e-02
# jump 2.284e+01, Exp jump1.777e+01, accept 0.920,log_a -5.580e-02, sldjxx 0.898,beta 3.835e-01, epsi 1.427e-02
# jump 2.012e+01, Exp jump1.717e+01, accept 0.896,log_a -1.058e-01, sldjxx 0.773,beta 3.968e-01, epsi 1.431e-02
# jump 2.295e+01, Exp jump1.951e+01, accept 0.915,log_a -6.679e-02, sldjxx 0.974,beta 4.142e-01, epsi 1.435e-02
# jump 2.390e+01, Exp jump1.628e+01, accept 0.899,log_a -8.217e-02, sldjxx 0.954,beta 4.287e-01, epsi 1.439e-02
# 1ksteps done, now 4000
# jump 1.909e+01, Exp jump1.640e+01, accept 0.917,log_a -5.178e-02, sldjxx 0.906,beta 4.402e-01, epsi 1.443e-02
# jump 2.067e+01, Exp jump1.647e+01, accept 0.911,log_a -7.109e-02, sldjxx 0.984,beta 4.448e-01, epsi 1.448e-02
# jump 2.523e+01, Exp jump1.677e+01, accept 0.921,log_a -5.736e-02, sldjxx 0.915,beta 4.290e-01, epsi 1.450e-02
# jump 1.451e+01, Exp jump1.275e+01, accept 0.911,log_a -8.978e-02, sldjxx 0.933,beta 4.401e-01, epsi 1.452e-02
# jump 3.207e+01, Exp jump2.148e+01, accept 0.896,log_a -7.494e-02, sldjxx 0.995,beta 4.150e-01, epsi 1.456e-02
# jump 2.102e+01, Exp jump1.169e+01, accept 0.875,log_a -1.348e-01, sldjxx 0.974,beta 4.073e-01, epsi 1.458e-02
# jump 2.527e+01, Exp jump2.087e+01, accept 0.913,log_a -5.683e-02, sldjxx 1.007,beta 4.213e-01, epsi 1.462e-02
# jump 2.658e+01, Exp jump1.595e+01, accept 0.898,log_a -1.373e-01, sldjxx 0.959,beta 4.257e-01, epsi 1.464e-02
# jump 2.651e+01, Exp jump2.102e+01, accept 0.901,log_a -2.059e-01, sldjxx 0.927,beta 4.105e-01, epsi 1.466e-02

# %% [markdown]
# ### Visualize learned proposal distribution
#
# Yellow dot is initial point, blue dots are accepted samples, black are rejected ones.

# %%
bs = 4096
x_init = torch.tensor([-2.,0.]).view(1,-1) #x at an extreme location, similar to Figure in the paper
#x_init = dist.sample(1) #Use this line for a random point from the distribution
x = x_init.expand((bs,data_dim)).clone()
xa, xp, accept_vect,_ = RW_controller.sample(x.clone(),1,grad=False,T=1)

plot_range = 8
res = 1024
Temp = 2 #temperature for better visuals
dist2d = dist
Eplot = dist2d.Ex
x = np.linspace(-plot_range,plot_range,res)
xx,yy = np.meshgrid(x,x)
xy_batch = np.stack([xx.flatten(),yy.flatten()],axis=1)
Exy = Eplot(torch.from_numpy(xy_batch).float())/Temp
Exy = Exy - Exy.min()
p_batch = (-Exy).exp().numpy()
p_batch = p_batch/p_batch.max()
p_batch = np.flip(p_batch.reshape(res,res),axis=0)

bkg_img = 1 - np.stack((0*p_batch,0.5*p_batch,0.5*p_batch),axis=2)


x_init_np = x_init.detach().cpu().numpy()
xp_np = xp.detach().cpu().numpy()
c_vect = accept_vect.detach().cpu().float().numpy()
c_vect = np.stack((0*c_vect,0.5*c_vect,1*c_vect),axis=1)
#xp_np = torch.randn_like(xp).cpu().numpy()
fig, ax = plt.subplots()
ax.imshow(bkg_img,extent=[-plot_range,plot_range,-plot_range,plot_range])
ax.scatter(xp_np[:,0],xp_np[:,1],s = 0.15,c=c_vect,alpha=0.1,marker=',')
ax.scatter(x_init_np[:,0],x_init_np[:,1],s=20,c='y')
ax.set_aspect(1)
ax.set_xlim(-plot_range,plot_range)
ax.set_ylim(-plot_range,plot_range)
# ax.set_axis_off()
plt.show()

# %% [markdown]
# ### Sample contimuously for 1000 steps

# %%
bs = 1024
x = dist.sample(bs)
x_list = []
for i in range(1000):
    x,xp,accept_vect,_ = RW_controller.sample(x,1,grad=False,print_log= True if i%100==0 else False,)
    x_list.append(x.clone())
# Out:
# accept 0.92578125
# accept 0.9169921875
# accept 0.9248046875
# accept 0.919921875
# accept 0.9228515625
# accept 0.91015625
# accept 0.912109375
# accept 0.9072265625
# accept 0.921875
# accept 0.9111328125

# %% [markdown]
# ### Visualize distribution in the batch at the last time point
#
# Should see fair samples from the moon distribution

# %%
xp_np = x_list[-1].detach().cpu().numpy()
fig, ax = plt.subplots()
ax.imshow(bkg_img,extent=[-plot_range,plot_range,-plot_range,plot_range])
ax.scatter(xp_np[:,0],xp_np[:,1],s = 0.6,alpha=0.2)
ax.set_aspect(1)
ax.set_xlim(-plot_range,plot_range)
ax.set_ylim(-plot_range,plot_range)
ax.set_axis_off()
plt.show()

# %% [markdown]
# ### Visualize the evolution of first dimension (horizontal axis),
#
# Should be a Gaussian with little correlation.

# %%
batch_i = 159
visualize_dim = 0 #change to 1 for the vertical axis
y_vect = torch.stack(x_list,dim=0)[0:,batch_i,visualize_dim].detach().cpu().numpy()
fig, ax = plt.subplots()
ax.plot(y_vect,'.')
y_mean, y_std = y_vect.mean(), y_vect.std()
print('y mean {}, y std {}'.format(y_mean.item(), y_std.item()))
# Out:
# y mean -0.1713760942220688, y std 2.9617526531219482
