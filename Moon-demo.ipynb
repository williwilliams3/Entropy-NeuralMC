# %% [markdown]
# # Demontration of neural network MCMC sampler trained with maximum Entropy objective

# %% [markdown]
# ## Please run Cells in the order provided.
#
# Requirements: pytorch 1.6.0 (cuda not required), numpy, matplotlib

# %% [markdown]
# ### First we import modules and setup the model

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from L2RW_models import L2GradRW, CovMALA
from L2RW import L2GradRW_M, adjust_lr
from distributions import distributions

# %%
data_dim = 2
dim = 32
N_steps = 2
dist = distributions('moon',d=data_dim)
RW = L2GradRW(dist.Ex,data_dim,dim,N_steps,epsi=0.01,net_type='MLP',grad_mode='R',bias=True,act='elu') #diag_gaussian example use 0.001 epsi init
RW_controller = L2GradRW_M(RW,beta=1e-2,beta_max=1e3,rho_beta=0.1,adapt_beta=True,a_target=0.9,
                 lr=1e-3,momo=0.9,rms_momo=0.95,grad_norm=10,N_steps=5000)

# %% [markdown]
# ### Train the Sampler
#
# sldjxx is the proposal entropy (up to a constant equal to the entropy of Gaussian), it should increase during training

# %%
#train with real samples
bs = 512
for i in range(5000):
    x_init = dist.sample(bs)
    x, accept_rate, sldjxx, L2jump = RW_controller.sample_train(x_init,T=1,print_log= (True if i%100==0 else False))
    #adjust_lr(RW_controller,i,warmup=False,min_lr=1e-2)
    if i>5 and i%1000 == 0:
        print('1ksteps done, now {}'.format(i))
# Out:
# jump 1.027e-04, Exp jump1.027e-04, accept 1.000,log_a -4.838e-07, sldjxx -9.210,beta 1.010e-02, epsi 1.001e-02
# jump 5.633e-03, Exp jump5.536e-03, accept 0.985,log_a -2.723e-03, sldjxx -5.238,beta 2.610e-02, epsi 1.110e-02
# jump 2.668e-01, Exp jump2.645e-01, accept 0.981,log_a 2.211e-04, sldjxx -1.830,beta 5.917e-02, epsi 1.221e-02
# jump 9.241e-01, Exp jump8.844e-01, accept 0.972,log_a -2.145e-03, sldjxx -1.089,beta 1.212e-01, epsi 1.289e-02
# jump 1.516e+00, Exp jump1.411e+00, accept 0.950,log_a -2.158e-02, sldjxx -0.494,beta 2.152e-01, epsi 1.337e-02
# jump 2.527e+00, Exp jump2.061e+00, accept 0.923,log_a -4.678e-02, sldjxx -0.115,beta 3.166e-01, epsi 1.395e-02
# jump 2.721e+00, Exp jump2.262e+00, accept 0.941,log_a -2.487e-02, sldjxx -0.022,beta 4.112e-01, epsi 1.425e-02
# jump 3.971e+00, Exp jump3.112e+00, accept 0.943,log_a -9.561e-03, sldjxx 0.024,beta 4.587e-01, epsi 1.439e-02
# jump 4.218e+00, Exp jump3.639e+00, accept 0.927,log_a -1.559e-02, sldjxx 0.092,beta 5.195e-01, epsi 1.454e-02
# jump 5.045e+00, Exp jump3.599e+00, accept 0.895,log_a -6.944e-02, sldjxx 0.171,beta 5.690e-01, epsi 1.459e-02
# jump 5.439e+00, Exp jump3.754e+00, accept 0.885,log_a -7.453e-02, sldjxx 0.183,beta 5.860e-01, epsi 1.465e-02
# 1ksteps done, now 1000
# jump 4.971e+00, Exp jump3.766e+00, accept 0.904,log_a -6.117e-02, sldjxx 0.166,beta 6.244e-01, epsi 1.469e-02
# jump 4.851e+00, Exp jump3.441e+00, accept 0.883,log_a -1.095e-01, sldjxx 0.214,beta 6.380e-01, epsi 1.473e-02
# jump 4.743e+00, Exp jump3.585e+00, accept 0.924,log_a -3.296e-02, sldjxx 0.162,beta 6.430e-01, epsi 1.477e-02
# jump 5.002e+00, Exp jump3.847e+00, accept 0.914,log_a -3.603e-02, sldjxx 0.197,beta 6.628e-01, epsi 1.480e-02
# jump 4.972e+00, Exp jump3.777e+00, accept 0.912,log_a -4.683e-02, sldjxx 0.166,beta 6.529e-01, epsi 1.482e-02
# jump 4.985e+00, Exp jump3.754e+00, accept 0.907,log_a -6.272e-02, sldjxx 0.185,beta 6.596e-01, epsi 1.486e-02
# jump 4.795e+00, Exp jump4.100e+00, accept 0.905,log_a -5.646e-02, sldjxx 0.189,beta 6.567e-01, epsi 1.488e-02
# jump 5.147e+00, Exp jump4.088e+00, accept 0.912,log_a -5.603e-02, sldjxx 0.176,beta 6.708e-01, epsi 1.492e-02
# jump 5.316e+00, Exp jump3.762e+00, accept 0.907,log_a -5.861e-02, sldjxx 0.195,beta 6.626e-01, epsi 1.495e-02
# jump 6.153e+00, Exp jump4.079e+00, accept 0.900,log_a -4.853e-02, sldjxx 0.230,beta 6.624e-01, epsi 1.499e-02
# 1ksteps done, now 2000
# jump 5.513e+00, Exp jump4.120e+00, accept 0.883,log_a -8.390e-02, sldjxx 0.222,beta 6.772e-01, epsi 1.499e-02
# jump 4.455e+00, Exp jump3.300e+00, accept 0.895,log_a -6.011e-02, sldjxx 0.246,beta 6.843e-01, epsi 1.501e-02
# jump 5.075e+00, Exp jump4.019e+00, accept 0.898,log_a -4.853e-02, sldjxx 0.217,beta 6.832e-01, epsi 1.504e-02
# jump 4.820e+00, Exp jump3.248e+00, accept 0.899,log_a -5.991e-02, sldjxx 0.233,beta 6.794e-01, epsi 1.507e-02
# jump 6.193e+00, Exp jump4.135e+00, accept 0.890,log_a -9.941e-02, sldjxx 0.221,beta 6.724e-01, epsi 1.508e-02
# jump 5.249e+00, Exp jump3.832e+00, accept 0.902,log_a -4.794e-02, sldjxx 0.216,beta 6.788e-01, epsi 1.511e-02
# jump 5.236e+00, Exp jump3.559e+00, accept 0.904,log_a -7.195e-02, sldjxx 0.198,beta 6.802e-01, epsi 1.513e-02
# jump 5.226e+00, Exp jump4.051e+00, accept 0.908,log_a -4.793e-02, sldjxx 0.212,beta 6.759e-01, epsi 1.516e-02
# jump 5.531e+00, Exp jump3.886e+00, accept 0.901,log_a -5.580e-02, sldjxx 0.215,beta 6.855e-01, epsi 1.518e-02
# jump 4.775e+00, Exp jump3.824e+00, accept 0.909,log_a -5.281e-02, sldjxx 0.205,beta 6.913e-01, epsi 1.521e-02
# 1ksteps done, now 3000
# jump 5.079e+00, Exp jump3.419e+00, accept 0.910,log_a -5.975e-02, sldjxx 0.219,beta 6.875e-01, epsi 1.522e-02
# jump 5.520e+00, Exp jump3.611e+00, accept 0.888,log_a -7.374e-02, sldjxx 0.224,beta 6.846e-01, epsi 1.524e-02
# jump 5.648e+00, Exp jump3.865e+00, accept 0.907,log_a -5.950e-02, sldjxx 0.189,beta 6.976e-01, epsi 1.527e-02
# jump 5.469e+00, Exp jump4.092e+00, accept 0.887,log_a -8.097e-02, sldjxx 0.234,beta 6.970e-01, epsi 1.528e-02
# jump 5.082e+00, Exp jump3.852e+00, accept 0.905,log_a -6.234e-02, sldjxx 0.212,beta 6.997e-01, epsi 1.529e-02
# jump 6.665e+00, Exp jump3.602e+00, accept 0.902,log_a -8.292e-02, sldjxx 0.222,beta 6.988e-01, epsi 1.530e-02
# jump 5.621e+00, Exp jump4.148e+00, accept 0.902,log_a -5.423e-02, sldjxx 0.226,beta 6.872e-01, epsi 1.532e-02
# jump 6.694e+00, Exp jump4.040e+00, accept 0.896,log_a -8.834e-02, sldjxx 0.209,beta 6.915e-01, epsi 1.532e-02
# jump 4.729e+00, Exp jump3.244e+00, accept 0.890,log_a -7.124e-02, sldjxx 0.261,beta 7.072e-01, epsi 1.534e-02
# jump 5.389e+00, Exp jump4.119e+00, accept 0.895,log_a -4.775e-02, sldjxx 0.251,beta 6.981e-01, epsi 1.536e-02
# 1ksteps done, now 4000
# jump 4.387e+00, Exp jump3.362e+00, accept 0.907,log_a -6.327e-02, sldjxx 0.208,beta 7.005e-01, epsi 1.536e-02
# jump 5.065e+00, Exp jump3.756e+00, accept 0.892,log_a -8.985e-02, sldjxx 0.224,beta 6.938e-01, epsi 1.537e-02
# jump 5.338e+00, Exp jump3.473e+00, accept 0.887,log_a -1.002e-01, sldjxx 0.255,beta 7.022e-01, epsi 1.539e-02
# jump 5.051e+00, Exp jump3.432e+00, accept 0.887,log_a -9.171e-02, sldjxx 0.240,beta 7.024e-01, epsi 1.539e-02
# jump 5.032e+00, Exp jump3.663e+00, accept 0.909,log_a -5.995e-02, sldjxx 0.198,beta 6.953e-01, epsi 1.541e-02
# jump 5.053e+00, Exp jump3.795e+00, accept 0.897,log_a -7.598e-02, sldjxx 0.220,beta 6.935e-01, epsi 1.542e-02
# jump 4.335e+00, Exp jump3.594e+00, accept 0.910,log_a -5.861e-02, sldjxx 0.206,beta 6.929e-01, epsi 1.542e-02
# jump 5.310e+00, Exp jump3.674e+00, accept 0.910,log_a -7.495e-02, sldjxx 0.195,beta 6.778e-01, epsi 1.544e-02
# jump 5.197e+00, Exp jump4.039e+00, accept 0.891,log_a -8.683e-02, sldjxx 0.224,beta 6.920e-01, epsi 1.546e-02

# %% [markdown]
# ### Visualize learned proposal distribution
#
# Yellow dot is initial point, blue dots are accepted samples, black are rejected ones.

# %%
bs = 4096
x_init = torch.tensor([-2.,0.]).view(1,-1) #x at an extreme location, similar to Figure in the paper
#x_init = dist.sample(1) #Use this line for a random point from the distribution
x = x_init.expand((bs,data_dim)).clone()
xa, xp, accept_vect,_ = RW_controller.sample(x.clone(),1,grad=False,T=1)

plot_range = 8
res = 1024
Temp = 2 #temperature for better visuals
dist2d = dist
Eplot = dist2d.Ex
x = np.linspace(-plot_range,plot_range,res)
xx,yy = np.meshgrid(x,x)
xy_batch = np.stack([xx.flatten(),yy.flatten()],axis=1)
Exy = Eplot(torch.from_numpy(xy_batch).float())/Temp
Exy = Exy - Exy.min()
p_batch = (-Exy).exp().numpy()
p_batch = p_batch/p_batch.max()
p_batch = np.flip(p_batch.reshape(res,res),axis=0)

bkg_img = 1 - np.stack((0*p_batch,0.5*p_batch,0.5*p_batch),axis=2)


x_init_np = x_init.detach().cpu().numpy()
xp_np = xp.detach().cpu().numpy()
c_vect = accept_vect.detach().cpu().float().numpy()
c_vect = np.stack((0*c_vect,0.5*c_vect,1*c_vect),axis=1)
#xp_np = torch.randn_like(xp).cpu().numpy()
fig, ax = plt.subplots()
ax.imshow(bkg_img,extent=[-plot_range,plot_range,-plot_range,plot_range])
ax.scatter(xp_np[:,0],xp_np[:,1],s = 0.15,c=c_vect,alpha=0.1,marker=',')
ax.scatter(x_init_np[:,0],x_init_np[:,1],s=20,c='y')
ax.set_aspect(1)
ax.set_xlim(-plot_range,plot_range)
ax.set_ylim(-plot_range,plot_range)
ax.set_axis_off()
plt.show()

# %% [markdown]
# ### Sample contimuously for 1000 steps

# %%
bs = 1024
x = dist.sample(bs)
x_list = []
for i in range(1000):
    x,xp,accept_vect,_ = RW_controller.sample(x,1,grad=False,print_log= True if i%100==0 else False,)
    x_list.append(x.clone())
# Out:
# accept 0.91796875
# accept 0.8955078125
# accept 0.9013671875
# accept 0.91015625
# accept 0.9072265625
# accept 0.9296875
# accept 0.9091796875
# accept 0.9052734375
# accept 0.9052734375
# accept 0.9228515625

# %% [markdown]
# ### Visualize distribution in the batch at the last time point
#
# Should see fair samples from the moon distribution

# %%
xp_np = x_list[-1].detach().cpu().numpy()
fig, ax = plt.subplots()
ax.imshow(bkg_img,extent=[-plot_range,plot_range,-plot_range,plot_range])
ax.scatter(xp_np[:,0],xp_np[:,1],s = 0.6,alpha=0.2)
ax.set_aspect(1)
ax.set_xlim(-plot_range,plot_range)
ax.set_ylim(-plot_range,plot_range)
ax.set_axis_off()
plt.show()

# %% [markdown]
# ### Visualize the evolution of first dimension (horizontal axis),
#
# Should be a Gaussian with little correlation.

# %%
batch_i = 159
visualize_dim = 0 #change to 1 for the vertical axis
y_vect = torch.stack(x_list,dim=0)[0:,batch_i,visualize_dim].detach().cpu().numpy()
fig, ax = plt.subplots()
ax.plot(y_vect,'.')
y_mean, y_std = y_vect.mean(), y_vect.std()
print('y mean {}, y std {}'.format(y_mean.item(), y_std.item()))
# Out:
# y mean -0.022561807185411453, y std 0.9838740229606628
